# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
print(arr, type(arr), arr.dtype)
print(arr, type(arr), arr.shape)

arr = np.array([1,2,3,4,5,"prime"])
print(arr2, type(arr2), arr2.dtype)
# Out:
# [1 2 3 4 5] <class 'numpy.ndarray'> int64
# [1 2 3 4 5] <class 'numpy.ndarray'> (5,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       3 print(arr, type(arr), arr.shape)
#       5 arr = np.array([1,2,3,4,5,"prime"])
# ----> 6 print(arr2, type(arr2), arr2.dtype)
#
# NameError: name 'arr2' is not defined

# %%
import time
#execution performance
size=1_000_000

#python list
py_list=list(range(size))
start=time.time()
sq_list=[x**2 for x in py_list]
end=time.time()
print(f"python list time ={end-start} seconds")

#numpy arrays
np_arr=np.array(py_list)
start=time.time()
sq_array=np_arr**2
end=time.time()
print(f"numpy array time={end-start} seconds")
# Out:
# python list time =0.034253597259521484 seconds
# numpy array time=0.0011632442474365234 seconds

# %%
#memory
import sys
print(f"python list size = {sys.getsizeof(py_list)*len(py_list)}bytes")
print(f"numpy array size = {np_arr.nbytes} bytes")
# Out:
# python list size = 8000056000000bytes
# numpy array size = 8000000 bytes
